# %%
import os
import numpy as np 
import pandas as pd
path = "D:/Github/Predict_the_time_of_arrival_for_the_delivery_persons/dataset/data"

# %%
# Đọc file csv 

df = pd.read_csv("../dataset/dataset.csv")

# %%
def date_time(date):
    date = str(date)
    if '23:60' in date:
        date = date.split(" ")
        date[0] = datetime.strptime(date[0], "%d-%m-%Y")
        date[1] = date[1].replace('23:60', "00:00")
        date[0] += timedelta(days=1)
        date[0] = str(date[0])
        date = date[0] + " " + date[1]
        date = date.replace('00:00:00', "")
        date = datetime.strptime(date, "%Y-%m-%d %H:%M")
        return date
    if '24:' in date:
        date = date.split(" ")
        date[0] = datetime.strptime(date[0], "%d-%m-%Y")
        date[1] = date[1].replace('24:', "00:")
        date[0] += timedelta(days=1)
        date[0] = str(date[0])
        date = date[0] + " " + date[1]
        date = date.replace('00:00:00', "")
        date = datetime.strptime(date, "%Y-%m-%d %H:%M")
        return date
    if ':60' in date:
        date = date.split(" ")
        date[0] = datetime.strptime(date[0], "%d-%m-%Y")
        date[0] = str(date[0])
        date[1] = date[1].replace('60', '00')
        date[1] = date[1].split(":")
        date[1] = str(int(date[1][0])+1) + ":" + date[1][1]
        date = date[0] + " " + date[1]
        date = date.replace('00:00:00', "")
        date = datetime.strptime(date, "%Y-%m-%d %H:%M")
        return date
    if '-' in date:
        date = date.split(" ")
        date[0] = datetime.strptime(date[0], "%d-%m-%Y")
        date[0] = str(date[0])
        date = date[0] + " " + date[1]
        date = date.replace('00:00:00', "")
        date = datetime.strptime(date, "%Y-%m-%d %H:%M")
        return date

# %%
df
# Out:
#        Unnamed: 0      ID Delivery_person_ID  Delivery_person_Age  \
# 0               0  0x9012   RANCHIRES09DEL02                 36.0
# 1               1  0xb201     BANGRES11DEL03                 37.0
# 2               2  0xa657      VADRES06DEL01                 25.0
# 3               3  0xab15      HYDRES05DEL02                 28.0
# 4               4  0x5be6      MYSRES13DEL02                 22.0
# ...           ...     ...                ...                  ...
# 45587       45587  0xc9bb     LUDHRES08DEL01                 26.0
# 45588       45588  0x3fb7      JAPRES15DEL02                 28.0
# 45589       45589  0xda5f      GOARES07DEL03                 30.0
# 45590       45590  0xdea0     KNPRES010DEL01                 20.0
# 45591       45591  0x1917      MYSRES15DEL02                 24.0
#
#        Delivery_person_ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.5            23.351058             85.325731
# 1                          4.7            12.934365             77.616155
# 2                          4.9            22.312790             73.170283
# 3                          4.5            17.433809             78.386744
# 4                          4.5            12.310972             76.659264
# ...                        ...                  ...                   ...
# 45587                      4.8            30.899992             75.831338
# 45588                      4.7            26.891191             75.802083
# 45589                      3.8            15.561295             73.749478
# 45590                      4.7            26.477750             80.351569
# 45591                      4.2            12.352058             76.606650
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_date  \
# 0                       23.371058                    85.345731  24-03-2022
# 1                       13.024365                    77.706155  25-03-2022
# 2                       22.352790                    73.210283  19-03-2022
# 3                       17.563809                    78.516744  10-03-2022
# 4                       12.390972                    76.739264  10-03-2022
# ...                           ...                          ...         ...
# 45587                   30.909992                    75.841338  11-02-2022
# 45588                   26.911191                    75.822083  15-03-2022
# 45589                   15.651295                    73.839478  12-02-2022
# 45590                   26.547750                    80.421569  18-02-2022
# 45591                   12.402058                    76.656650  09-03-2022
#
#        ... Time_order_picked Weather_conditions Road_traffic_density  \
# 0      ...             11:35             Cloudy                 High
# 1      ...             17:50                Fog               Medium
# 2      ...             13:55             Cloudy                 High
# 3      ...             23:45         Sandstorms                  Low
# 4      ...             20:55                Fog                  Jam
# ...    ...               ...                ...                  ...
# 45587  ...             10:05             Cloudy                  Low
# 45588  ...              9:15             Stormy                  Low
# 45589  ...             23:35                Fog                  Low
# 45590  ...             23:45         Sandstorms                  Low
# 45591  ...             23:25             Stormy                  Low
#
#       Vehicle_condition  Type_of_order Type_of_vehicle Multiple_deliveries  \
# 0                     1         Drinks      motorcycle                 1.0
# 1                     1           Meal         scooter                 1.0
# 2                     1         Drinks         scooter                 1.0
# 3                     1         Drinks      motorcycle                 0.0
# 4                     0          Snack      motorcycle                 1.0
# ...                 ...            ...             ...                 ...
# 45587                 0         Drinks      motorcycle                 0.0
# 45588                 2          Snack         scooter                 1.0
# 45589                 1         Drinks         scooter                 1.0
# 45590                 0          Snack      motorcycle                 0.0
# 45591                 0         Drinks      motorcycle                 0.0
#
#        Festival           City Time_taken_(min)
# 0            No  Metropolitian             25.0
# 1            No  Metropolitian             40.0
# 2            No          Urban             30.0
# 3            No  Metropolitian             11.0
# 4            No  Metropolitian             47.0
# ...         ...            ...              ...
# 45587        No  Metropolitian             21.0
# 45588        No  Metropolitian             18.0
# 45589        No          Urban             35.0
# 45590        No  Metropolitian             18.0
# 45591        No  Metropolitian             17.0
#
# [45592 rows x 21 columns]

# %%
# del df['Unnamed: 0']
# del df['ID']
# del df['Delivery_person_ID']

# %%
time_range = []
for i in range(len(df)):
    if '2022' in str(df['Time_order'][i]):
        time_range.append(df['Time_order_picked'][i] - df['Time_order'][i])

# %%
import random 
from datetime import datetime

# %%
for i in range(len(df)):
    if '2022' in str(df['Time_order'][i]):
        continue
    else:
        df['Time_order'][i] = df['Time_order_picked'][i] - random.choice(time_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Github\Predict_the_time_of_arrival_for_the_delivery_persons\src\Predict_the_time_of_arrival_for_the_delivery_persons.ipynb Cell 7 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     continue
#       <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> else:
# ----> <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     df['Time_order'][i] = df['Time_order_picked'][i] - random.choice(time_range)
#
# NameError: name 'random' is not defined

# %%
df
# Out:
#        Order_date           Time_order    Time_order_picked
# 0      24-03-2022  2022-03-24 11:25:00  2022-03-24 11:35:00
# 1      25-03-2022  2022-03-25 17:40:00  2022-03-25 17:50:00
# 2      19-03-2022  2022-03-19 13:40:00  2022-03-19 13:55:00
# 3      10-03-2022  2022-03-10 23:35:00  2022-03-10 23:45:00
# 4      10-03-2022  2022-03-10 20:40:00  2022-03-10 20:55:00
# ...           ...                  ...                  ...
# 45587  11-02-2022  2022-02-11 10:00:00  2022-02-11 10:05:00
# 45588  15-03-2022  2022-03-15 09:00:00  2022-03-15 09:15:00
# 45589  12-02-2022  2022-02-12 23:25:00  2022-02-12 23:35:00
# 45590  18-02-2022  2022-02-18 23:30:00  2022-02-18 23:45:00
# 45591  09-03-2022  2022-03-09 23:20:00  2022-03-09 23:25:00
#
# [45592 rows x 3 columns]

# %%
np.mean(time_range)
# Out:
# datetime.timedelta(seconds=599, microseconds=357060)

# %%
import random

# %%
df['Time_order'] = df['Order_date'] + ' ' + df['Time_order']

df['Time_order_picked'] = df['Order_date'] + ' ' + df['Time_order_picked']
# Out:
# C:\Users\DUCNM\AppData\Local\Temp\ipykernel_35508\4126040939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time_order'] = df['Order_date'] + ' ' + df['Time_order']
# C:\Users\DUCNM\AppData\Local\Temp\ipykernel_35508\4126040939.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time_order_picked'] = df['Order_date'] + ' ' + df['Time_order_picked']

# %%
df.isnull().sum()
# Out:
# Order_date              0
# Time_order           1731
# Time_order_picked       0
# dtype: int64

# %%
for i in range(len(df)):
    df['Time_order'][i] = date_time(df['Time_order'][i])
    df['Time_order_picked'][i] = date_time(df['Time_order_picked'][i])
# Out:
# C:\Users\DUCNM\AppData\Local\Temp\ipykernel_35508\1794767946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time_order'][i] = date_time(df['Time_order'][i])
# C:\Users\DUCNM\AppData\Local\Temp\ipykernel_35508\1794767946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time_order_picked'][i] = date_time(df['Time_order_picked'][i])

# %%
# for i in range(len(df)):
#         if sum(np.array(df[i:i+1].isnull().sum())) > 3:
#             df = df.drop(df[i:i+1].index)

# %%
# import random 
# df["Delivery_person_Age"] = df["Delivery_person_Age"].replace(to_replace = np.NaN, value= random.choice(np.array(df["Delivery_person_Age"])))
# df["Multiple_deliveries"] = df["Multiple_deliveries"].replace(to_replace = np.NaN, value= random.choice(np.array(df["Multiple_deliveries"])))
# df["Road_traffic_density"] = df["Road_traffic_density"].replace(to_replace = np.NaN, value= random.choice(np.array(df["Road_traffic_density"])))
# df["Weather_conditions"] = df["Weather_conditions"].replace(to_replace = np.NaN, value= random.choice(np.array(df["Weather_conditions"])))
# df["Delivery_person_ratings"] = df["Delivery_person_ratings"].replace(to_replace = np.NaN, value= random.choice(np.array(df["Delivery_person_ratings"])))

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_date                        0
# Time_order                        0
# Time_order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# Multiple_deliveries               0
# Festival                        228
# City                           1200
# Time_taken_(min)                  0
# dtype: int64

# %%
# import math 
# # Tính khoảng cách giữa cửa hàng và nơi giao hàng 
# def distance(lat1, lon1, lat2, lon2):
#     p = 0.017453292519943295;   
#     c = math.cos
#     a = 0.5 - c((lat2 - lat1) * p)/2 + c(lat1 * p) * c(lat2 * p) * (1 - c((lon2 - lon1) * p))/2

#     return 12742 * math.asin(math.sqrt(a))

# %%
# df["Distance"] = 0

# for i in range(len(df)):
#     df["Distance"][i:i+1] = distance(df["Restaurant_latitude"][i:i+1], df["Restaurant_longitude"][i:i+1],
#                                      df["Delivery_location_latitude"][i:i+1],df["Delivery_location_longitude"][i:i+1])

# %%
a = df['Time_order']

# %%
df['Order_date'].unique()
# Out:
# array(['24-03-2022', '25-03-2022', '19-03-2022', '10-03-2022',
#        '03-04-2022', '15-02-2022', '13-02-2022', '11-02-2022',
#        '01-04-2022', '02-04-2022', '27-03-2022', '17-02-2022',
#        '16-02-2022', '09-03-2022', '13-03-2022', '20-03-2022',
#        '12-03-2022', '31-03-2022', '18-03-2022', '11-03-2022',
#        '12-02-2022', '04-03-2022', '01-03-2022', '17-03-2022',
#        '30-03-2022', '18-02-2022', '14-03-2022', '03-03-2022',
#        '05-04-2022', '06-03-2022', '04-04-2022', '15-03-2022',
#        '16-03-2022', '26-03-2022', '29-03-2022', '08-03-2022',
#        '21-03-2022', '28-03-2022', '02-03-2022', '14-02-2022',
#        '07-03-2022', '23-03-2022', '05-03-2022', '06-04-2022'],
#       dtype=object)

# %%
from datetime import datetime

# %%
# for i in range(len(df)):
#     df['Order_date'][i] = datetime.strptime(df['Order_date'][i], "%d-%m-%Y") 
#     df['Time_order'][i] = datetime.strptime(df['Time_order'][i], "%H:%M")
#     df['Time_order_picked'][i] = datetime.strptime(df['Time_order_picked'][i], "%H:%M")

# %%
a = '24-03-2022 8:30' 
b = '25-03-2022 8:30'

a = datetime.strptime(a, "%d-%m-%Y %H:%M")
b = datetime.strptime(b, "%d-%m-%Y %H:%M")

c = b-a
print(c)
# Out:
# 1 day, 0:00:00

# %%
a + c + c
# Out:
# datetime.datetime(2022, 3, 26, 8, 30)

# %%
a = '8:30' 
b = '8:40'

a = datetime.strptime(a, "%H:%M")
b = datetime.strptime(b, "%H:%M")

# %%
from datetime import datetime

# %%
a = '24-03-2022' +' ' '11:25'
a
# Out:
# '24-03-2022 11:25'

# %%
# for i in range(len(df)):
#     df['Time_order'][i] = datetime.strptime(df['Time_order'][i], "%d-%m-%Y %H:%M")
#     df['Time_order_picked'][i] = datetime.strptime(df['Time_order_picked'][i], "%d-%m-%Y %H:%M")

# %%
data_time_order_notnull = np.array(df[df['Time_order'] > str(0)]['Time_order'])
data_time_order_picked_notnull = np.array(df[df['Time_order'] > str(0)]['Time_order_picked'])

# %%
from datetime import timedelta

# %%
def date_time(date):
    date = str(date)
    if '23:60' in date:
        date = date.split(" ")
        date[0] = datetime.strptime(date[0], "%d-%m-%Y")
        date[1] = date[1].replace('23:60', "00:00")
        date[0] += timedelta(days=1)
        date[0] = str(date[0])
        date = date[0] + " " + date[1]
        date = date.replace('00:00:00', "")
        date = datetime.strptime(date, "%Y-%m-%d %H:%M")
        return date
    if '24:' in date:
        date = date.split(" ")
        date[0] = datetime.strptime(date[0], "%d-%m-%Y")
        date[1] = date[1].replace('24:', "00:")
        date[0] += timedelta(days=1)
        date[0] = str(date[0])
        date = date[0] + " " + date[1]
        date = date.replace('00:00:00', "")
        date = datetime.strptime(date, "%Y-%m-%d %H:%M")
        return date
    if ':60' in date:
        date = date.split(" ")
        date[0] = datetime.strptime(date[0], "%d-%m-%Y")
        date[0] = str(date[0])
        date[1] = date[1].replace('60', '00')
        date[1] = date[1].split(":")
        date[1] = str(int(date[1][0])+1) + ":" + date[1][1]
        date = date[0] + " " + date[1]
        date = date.replace('00:00:00', "")
        date = datetime.strptime(date, "%Y-%m-%d %H:%M")
        return date
    if '-' in date:
        date = date.split(" ")
        date[0] = datetime.strptime(date[0], "%d-%m-%Y")
        date[0] = str(date[0])
        date = date[0] + " " + date[1]
        date = date.replace('00:00:00', "")
        date = datetime.strptime(date, "%Y-%m-%d %H:%M")
        return date
    return date

# %%
print(date_time('24-03-2022 24:60'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Github\Predict_the_time_of_arrival_for_the_delivery_persons\src\Predict_the_time_of_arrival_for_the_delivery_persons.ipynb Cell 32 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y166sZmlsZQ%3D%3D?line=0'>1</a> print(date_time('24-03-2022 24:60'))
#
# d:\Github\Predict_the_time_of_arrival_for_the_delivery_persons\src\Predict_the_time_of_arrival_for_the_delivery_persons.ipynb Cell 32 in date_time(date)
#      <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y166sZmlsZQ%3D%3D?line=18'>19</a>     date = date[0] + " " + date[1]
#      <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y166sZmlsZQ%3D%3D?line=19'>20</a>     date = date.replace('00:00:00', "")
# ---> <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y166sZmlsZQ%3D%3D?line=20'>21</a>     date = datetime.strptime(date, "%Y-%m-%d %H:%M")
#      <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y166sZmlsZQ%3D%3D?line=21'>22</a>     return date
#      <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y166sZmlsZQ%3D%3D?line=22'>23</a> if ':60' in date:
#
# File d:\AppDownload\Settingg\anaconda3\envs\DataScientist\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File d:\AppDownload\Settingg\anaconda3\envs\DataScientist\lib\_strptime.py:352, in _strptime(data_string, format)
#     349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
# --> 352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#     355 iso_year = year = None
#     356 month = day = 1
#
# ValueError: unconverted data remains: 0

# %%
a = '24-03-2022 00:25'
if '26' in a:
    print(5)
a = a.split(" ")

# %%
a[0]
# Out:
# '24-03-2022'

# %%
a = '00:00'
a = a.replace('60','00')

a = a.split(":") 

a = str(int(a[0])+1) + ":" + a[1]
a
# Out:
# '1:00'

# %%
for i in range(18):
    data_time_order_notnull[i] = datetime.strptime(data_time_order_notnull[i], "%H:%M")
    #data_time_order_picked_notnull[i] = datetime.strptime(data_time_order_picked_notnull[i], "%H:%M")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Github\Predict_the_time_of_arrival_for_the_delivery_persons\src\Predict_the_time_of_arrival_for_the_delivery_persons.ipynb Cell 28 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y141sZmlsZQ%3D%3D?line=0'>1</a> for i in range(18):
# ----> <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y141sZmlsZQ%3D%3D?line=1'>2</a>     data_time_order_notnull[i] = datetime.strptime(data_time_order_notnull[i], "%H:%M")
#
# File d:\AppDownload\Settingg\anaconda3\envs\DataScientist\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File d:\AppDownload\Settingg\anaconda3\envs\DataScientist\lib\_strptime.py:352, in _strptime(data_string, format)
#     349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
# --> 352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#     355 iso_year = year = None
#     356 month = day = 1
#
# ValueError: unconverted data remains: 0

# %%
data_time_order_notnull[:20]
# Out:
# array([datetime.datetime(1900, 1, 1, 11, 25),
#        datetime.datetime(1900, 1, 1, 17, 40),
#        datetime.datetime(1900, 1, 1, 13, 40),
#        datetime.datetime(1900, 1, 1, 23, 35),
#        datetime.datetime(1900, 1, 1, 20, 40),
#        datetime.datetime(1900, 1, 1, 10, 45),
#        datetime.datetime(1900, 1, 1, 9, 40),
#        datetime.datetime(1900, 1, 1, 8, 30),
#        datetime.datetime(1900, 1, 1, 18, 35),
#        datetime.datetime(1900, 1, 1, 8, 20),
#        datetime.datetime(1900, 1, 1, 20, 45),
#        datetime.datetime(1900, 1, 1, 18, 15),
#        datetime.datetime(1900, 1, 1, 21, 30),
#        datetime.datetime(1900, 1, 1, 18, 25),
#        datetime.datetime(1900, 1, 1, 23, 40),
#        datetime.datetime(1900, 1, 1, 13, 55),
#        datetime.datetime(1900, 1, 1, 14, 40), '10:60', '12:55', '9:25'],
#       dtype=object)

# %%
a = '24:00'
a = datetime.strptime(a, "%H:%M") 
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Github\Predict_the_time_of_arrival_for_the_delivery_persons\src\Predict_the_time_of_arrival_for_the_delivery_persons.ipynb Cell 33 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y146sZmlsZQ%3D%3D?line=0'>1</a> a = '24:00'
# ----> <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y146sZmlsZQ%3D%3D?line=1'>2</a> a = datetime.strptime(a, "%H:%M")
#       <a href='vscode-notebook-cell:/d%3A/Github/Predict_the_time_of_arrival_for_the_delivery_persons/src/Predict_the_time_of_arrival_for_the_delivery_persons.ipynb#Y146sZmlsZQ%3D%3D?line=2'>3</a> print(a)
#
# File d:\AppDownload\Settingg\anaconda3\envs\DataScientist\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File d:\AppDownload\Settingg\anaconda3\envs\DataScientist\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '24:00' does not match format '%H:%M'

# %%
set_data_time_order = set(data_time_order_picked_notnull)

# %%
a = np.array(set_data_time_order)

# %%
a
# Out:
# array({'16:05', '20:15', '23:05', '19:30', '15:30', '22:10', '17:45', '15:50', '10:15', '14:20', '21:20', '13:50', '18:40', '10:60', '19:05', '8:50', '22:45', '13:10', '10:50', '18:05', '16:35', '17:20', '24:05', '20:40', '16:30', '18:50', '17:60', '20:10', '8:25', '13:55', '23:40', '22:40', '18:15', '17:55', '9:15', '10:20', '8:40', '22:25', '9:10', '14:35', '16:25', '18:45', '18:55', '22:55', '21:40', '14:50', '11:40', '14:25', '17:40', '12:50', '16:10', '19:15', '21:35', '9:25', '14:15', '17:10', '22:60', '8:45', '12:60', '10:05', '13:20', '19:25', '10:25', '11:30', '17:50', '9:55', '19:55', '18:20', '10:10', '12:25', '13:05', '13:30', '22:15', '19:40', '20:35', '9:40', '15:60', '21:25', '23:55', '23:45', '13:40', '12:30', '12:20', '23:50', '14:45', '13:15', '13:25', '19:20', '14:10', '20:20', '10:30', '9:45', '11:50', '11:25', '11:15', '15:10', '8:30', '16:40', '9:05', '11:45', '8:35', '12:55', '11:20', '24:15', '11:05', '15:20', '12:15', '9:30', '21:15', '23:35', '22:05', '15:35', '15:15', '16:60', '16:20', '11:55', '11:60', '13:35', '9:50', '23:25', '12:05', '9:20', '16:50', '19:10', '21:55', '23:30', '23:20', '15:55', '20:30', '8:15', '18:30', '8:55', '15:45', '15:25', '17:05', '11:35', '20:60', '13:60', '21:50', '23:60', '9:35', '16:55', '24:10', '12:45', '10:45', '20:45', '23:15', '10:55', '14:55', '8:60', '14:40', '15:40', '17:15', '12:35', '12:10', '19:60', '19:45', '22:30', '11:10', '8:20', '17:30', '20:25', '14:05', '22:50', '21:10', '21:60', '19:50', '20:55', '21:30', '18:10', '18:60', '22:35', '20:50', '19:35', '16:45', '9:60', '16:15', '17:25', '15:05', '14:60', '20:05', '17:35', '14:30', '12:40', '10:40', '21:45', '21:05', '23:10', '18:25', '10:35', '22:20', '13:45', '18:35'},
#       dtype=object)

# %%
df[df['Time_order'] > str(0)]['Time_order']
# Out:
# 0        11:25
# 1        17:40
# 2        13:40
# 3        23:35
# 4        20:40
#          ...
# 45587     9:60
# 45588     8:60
# 45589    23:25
# 45590    23:30
# 45591    23:20
# Name: Time_order, Length: 43861, dtype: object

# %%
a.isnull().sum()
# Out:
# 1139

# %%
a = '24-03-2022 8:30'
a = datetime.strptime(a, "%d-%m-%Y %H:%M")

# %%
print(a)
# Out:
# 2022-03-24 11:25:00

# %%
df.isnull().sum()
# Out:
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_date                        0
# Time_order                     1731
# Time_order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# Multiple_deliveries             993
# Festival                          0
# City                           1200
# Time_taken_(min)                  0
# Index                             0
# Distance                          0
# dtype: int64

# %%
np.array(df["Order_date"])
# Out:
# array(['24-03-2022', '25-03-2022', '19-03-2022', ..., '12-02-2022',
#        '18-02-2022', '09-03-2022'], dtype=object)

# %%
from datetime import datetime
a = '8:30:00' 
dt_object1 = datetime.strptime(a, "%H:%M:%S")

# %%
dt_object1.strftime("%H")
# Out:
# '08'

# %%
res_las = np.array(df['Restaurant_latitude'])

np.sort(res_las)
# Out:
# array([-30.905562, -30.902872, -30.902872, ...,  30.914057,  30.914057,
#         30.914057])

# %%
print(len(res_las))

print(len(set(res_las)))
# Out:
# 45592
# 657

# %%
dis = np.array(df['Distance'])

dis
# Out:
# array([ 3.01891148, 13.97317756,  6.05882517, ..., 13.89436656,
#        10.44497153,  7.7718343 ])

# %%
set(dis)
# Out:
# {1.5147814029387021,
#  2.979521050245772,
#  3.104632094129702,
#  4.674174528666633,
#  4.656983637835054,
#  6.058825169237242,
#  6.29013467758336,
#  4.596336792048561,
#  9.435201537103644,
#  6.118711846640849,
#  11.917680464440235,
#  6.119039466421071,
#  6.210607623138685,
#  7.546267707012646,
#  8.811839531264553,
#  16.63531520323739,
#  17.073624954178904,
#  16.660097204528178,
#  19.975520086223586,
#  20.178267239101707,
#  19.97609532002721,
#  20.442929762531403,
#  16.60127679032794,
#  16.830914549936686,
#  17.139219742239916,
#  19.363204222098958,
#  20.25296785008508,
py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Index"][i:i+1] = i

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_date                        0
# Time_order                     1731
# Time_order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# Multiple_deliveries             993
# Festival                          0
# City                           1200
# Time_taken_(min)                  0
# Index                             0
# Distance                          0
# dtype: int64

# %%
len(df)
# Out:
# 45592

# %%
revgc.search((0, 0))
# Out:
# [{'lat': '4.88447',
#   'lon': '-1.75536',
#   'name': 'Takoradi',
#   'admin1': 'Western',
#   'admin2': '',
#   'cc': 'GH'}]

# %%
data_2[data_2["City"]=="Metropolitian"]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 12     0xc544      GOARES20DEL03                 22.0
# 110    0xcedc      KOLRES08DEL03                 34.0
# 134    0xc09e      ALHRES03DEL02                 32.0
# 257    0xc0f9      AGRRES06DEL03                 33.0
# 362    0xc7b0      GOARES18DEL01                 34.0
# ...       ...                ...                  ...
# 45158  0xd363      AGRRES05DEL03                 20.0
# 45184  0xd0d1      DEHRES14DEL03                  NaN
# 45452  0xc196      AGRRES12DEL01                 33.0
# 45581  0xd48e      ALHRES19DEL02                 35.0
# 45584  0xd163      KNPRES14DEL01                 36.0
#
#        Delivery_person_ratings  Restaurant_latitude  Restaurant_longitude  \
# 12                         4.9             0.000000              0.000000
# 110                        4.1            22.537960             88.349843
# 134                        5.0           -25.451517             81.832616
# 257                        4.5            -0.000000              0.000000
# 362                        4.5            15.493950             73.827423
# ...                        ...                  ...                   ...
# 45158                      4.8            27.201725             78.007553
# 45184                      NaN            30.319528             78.040267
# 45452                      4.8            27.165108             78.015053
# 45581                      4.7            25.457116             81.859682
# 45584                      4.8            26.463504             80.372929
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_date  \
# 12                       0.060000                     0.060000  17-02-2022
# 110                     22.567960                    88.379843  17-02-2022
# 134                     25.471517                    81.852616  17-02-2022
# 257                      0.030000                     0.030000  17-02-2022
# 362                     15.533950                    73.867423  17-02-2022
# ...                           ...                          ...         ...
# 45158                   27.261725                    78.067553  17-02-2022
# 45184                   30.379528                    78.100267  17-02-2022
# 45452                   27.205108                    78.055053  17-02-2022
# 45581                   25.507116                    81.909682  17-02-2022
# 45584                   26.503504                    80.412929  17-02-2022
#
#       Time_order  ... Weather_conditions Road_traffic_density  \
# 12         21:30  ...              Sunny                  Jam
# 110        23:35  ...         Sandstorms                  Low
# 134        11:40  ...                Fog                 High
# 257        19:45  ...             Stormy                  Jam
# 362        15:55  ...                Fog               Medium
# ...          ...  ...                ...                  ...
# 45158      22:40  ...              Sunny                  Low
# 45184        NaN  ...         Sandstorms                  Jam
# 45452      16:25  ...             Cloudy               Medium
# 45581      22:50  ...             Stormy                  Low
# 45584      14:30  ...              Sunny                 High
#
#       Vehicle_condition  Type_of_order Type_of_vehicle Multiple_deliveries  \
# 12                    2           Meal         scooter                 NaN
# 110                   0         Buffet      motorcycle                 1.0
# 134                   0         Drinks      motorcycle                 1.0
# 257                   2         Buffet         scooter                 1.0
# 362                   2          Snack         scooter                 0.0
# ...                 ...            ...             ...                 ...
# 45158                 0          Snack      motorcycle                 1.0
# 45184                 0           Meal      motorcycle                 1.0
# 45452                 2           Meal         scooter                 0.0
# 45581                 2         Drinks      motorcycle                 1.0
# 45584                 1          Snack         scooter                 1.0
#
#        Festival           City Time_taken_(min)  Index
# 12           No  Metropolitian             14.0     12
# 110          No  Metropolitian             22.0    110
# 134          No  Metropolitian             27.0    134
# 257          No  Metropolitian             29.0    257
# 362          No  Metropolitian             17.0    362
# ...         ...            ...              ...    ...
# 45158        No  Metropolitian             18.0  45158
# 45184        No  Metropolitian             40.0  45184
# 45452        No  Metropolitian             17.0  45452
# 45581        No  Metropolitian             27.0  45581
# 45584        No  Metropolitian             17.0  45584
#
# [674 rows x 21 columns]

# %% [markdown]
# Time_order_picked không có giá trị NaN
# Time_order có giá trị NaN

# %% [markdown]
# % ngày thường chiếm đều ~98%
# => nhóm sẽ chuyển Festival sang giá trị No

# %%
df
# Out:
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                23.351058             85.325731                   23.371058
# 1                12.934365             77.616155                   13.024365
# 2                22.312790             73.170283                   22.352790
# 3                17.433809             78.386744                   17.563809
# 4                12.310972             76.659264                   12.390972
# ...                    ...                   ...                         ...
# 45587            30.899992             75.831338                   30.909992
# 45588            26.891191             75.802083                   26.911191
# 45589            15.561295             73.749478                   15.651295
# 45590            26.477750             80.351569                   26.547750
# 45591            12.352058             76.606650                   12.402058
#
#        Delivery_location_longitude  Order_date Time_order Time_order_picked  \
# 0                        85.345731  24-03-2022      11:25             11:35
# 1                        77.706155  25-03-2022      17:40             17:50
# 2                        73.210283  19-03-2022      13:40             13:55
# 3                        78.516744  10-03-2022      23:35             23:45
# 4                        76.739264  10-03-2022      20:40             20:55
# ...                            ...         ...        ...               ...
# 45587                    75.841338  11-02-2022       9:60             10:05
# 45588                    75.822083  15-03-2022       8:60              9:15
# 45589                    73.839478  12-02-2022      23:25             23:35
# 45590                    80.421569  18-02-2022      23:30             23:45
# 45591                    76.656650  09-03-2022      23:20             23:25
#
#       Weather_conditions Road_traffic_density  Vehicle_condition  \
# 0                 Cloudy                 High                  1
# 1                    Fog               Medium                  1
# 2                 Cloudy                 High                  1
# 3             Sandstorms                  Low                  1
# 4                    Fog                  Jam                  0
# ...                  ...                  ...                ...
# 45587             Cloudy                  Low                  0
# 45588             Stormy                  Low                  2
# 45589                Fog                  Low                  1
# 45590         Sandstorms                  Low                  0
# 45591             Stormy                  Low                  0
#
#       Type_of_order Type_of_vehicle  Multiple_deliveries Festival  \
# 0            Drinks      motorcycle                  1.0       No
# 1              Meal         scooter                  1.0       No
# 2            Drinks         scooter                  1.0       No
# 3            Drinks      motorcycle                  0.0       No
# 4             Snack      motorcycle                  1.0       No
# ...             ...             ...                  ...      ...
# 45587        Drinks      motorcycle                  0.0       No
# 45588         Snack         scooter                  1.0       No
# 45589        Drinks         scooter                  1.0       No
# 45590         Snack      motorcycle                  0.0       No
# 45591        Drinks      motorcycle                  0.0       No
#
#                 City  Time_taken_(min)
# 0      Metropolitian              25.0
# 1      Metropolitian              40.0
# 2              Urban              30.0
# 3      Metropolitian              11.0
# 4      Metropolitian              47.0
# ...              ...               ...
# 45587  Metropolitian              21.0
# 45588  Metropolitian              18.0
# 45589          Urban              35.0
# 45590  Metropolitian              18.0
# 45591  Metropolitian              17.0
#
# [45592 rows x 16 columns]

# %%
df[df['Festival'] == "No"]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x9012   RANCHIRES09DEL02                 36.0
# 1      0xb201     BANGRES11DEL03                 37.0
# 2      0xa657      VADRES06DEL01                 25.0
# 3      0xab15      HYDRES05DEL02                 28.0
# 4      0x5be6      MYSRES13DEL02                 22.0
# ...       ...                ...                  ...
# 45587  0xc9bb     LUDHRES08DEL01                 26.0
# 45588  0x3fb7      JAPRES15DEL02                 28.0
# 45589  0xda5f      GOARES07DEL03                 30.0
# 45590  0xdea0     KNPRES010DEL01                 20.0
# 45591  0x1917      MYSRES15DEL02                 24.0
#
#        Delivery_person_ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.5            23.351058             85.325731
# 1                          4.7            12.934365             77.616155
# 2                          4.9            22.312790             73.170283
# 3                          4.5            17.433809             78.386744
# 4                          4.5            12.310972             76.659264
# ...                        ...                  ...                   ...
# 45587                      4.8            30.899992             75.831338
# 45588                      4.7            26.891191             75.802083
# 45589                      3.8            15.561295             73.749478
# 45590                      4.7            26.477750             80.351569
# 45591                      4.2            12.352058             76.606650
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_date  \
# 0                       23.371058                    85.345731  24-03-2022
# 1                       13.024365                    77.706155  25-03-2022
# 2                       22.352790                    73.210283  19-03-2022
# 3                       17.563809                    78.516744  10-03-2022
# 4                       12.390972                    76.739264  10-03-2022
# ...                           ...                          ...         ...
# 45587                   30.909992                    75.841338  11-02-2022
# 45588                   26.911191                    75.822083  15-03-2022
# 45589                   15.651295                    73.839478  12-02-2022
# 45590                   26.547750                    80.421569  18-02-2022
# 45591                   12.402058                    76.656650  09-03-2022
#
#       Time_order  ... Weather_conditions Road_traffic_density  \
# 0          11:25  ...             Cloudy                 High
# 1          17:40  ...                Fog               Medium
# 2          13:40  ...             Cloudy                 High
# 3          23:35  ...         Sandstorms                  Low
# 4          20:40  ...                Fog                  Jam
# ...          ...  ...                ...                  ...
# 45587       9:60  ...             Cloudy                  Low
# 45588       8:60  ...             Stormy                  Low
# 45589      23:25  ...                Fog                  Low
# 45590      23:30  ...         Sandstorms                  Low
# 45591      23:20  ...             Stormy                  Low
#
#       Vehicle_condition  Type_of_order Type_of_vehicle Multiple_deliveries  \
# 0                     1         Drinks      motorcycle                 1.0
# 1                     1           Meal         scooter                 1.0
# 2                     1         Drinks         scooter                 1.0
# 3                     1         Drinks      motorcycle                 0.0
# 4                     0          Snack      motorcycle                 1.0
# ...                 ...            ...             ...                 ...
# 45587                 0         Drinks      motorcycle                 0.0
# 45588                 2          Snack         scooter                 1.0
# 45589                 1         Drinks         scooter                 1.0
# 45590                 0          Snack      motorcycle                 0.0
# 45591                 0         Drinks      motorcycle                 0.0
#
#        Festival           City Time_taken_(min)  Index
# 0            No  Metropolitian             25.0      0
# 1            No  Metropolitian             40.0      1
# 2            No          Urban             30.0      2
# 3            No  Metropolitian             11.0      3
# 4            No  Metropolitian             47.0      4
# ...         ...            ...              ...    ...
# 45587        No  Metropolitian             21.0  45587
# 45588        No  Metropolitian             18.0  45588
# 45589        No          Urban             35.0  45589
# 45590        No  Metropolitian             18.0  45590
# 45591        No  Metropolitian             17.0  45591
#
# [44696 rows x 21 columns]

# %%
list_date = df["Order_date"].unique()

arr = []
df_date_festival = pd.DataFrame(arr, columns=["Date", "Festival: Yes", "Festival: No", "Festival: NaN", "% No"])

list = []
for date in list_date:
    yes = (df[df["Order_date"]==date]['Festival'] == "Yes").sum()
    no =  (df[df["Order_date"]==date]['Festival'] == "No").sum()
    nan = len(df[df["Order_date"]==date]) - yes - no 
    a = [date, yes, no, nan, float(no/(no+yes)*100)]
    list.append(a)

for i in range(len(list)):
    df_date_festival.loc[i] = list[i]


df_date_festival
# Out:
#           Date  Festival: Yes  Festival: No  Festival: NaN       % No
# 0   24-03-2022              6          1147              9  99.479618
# 1   25-03-2022             45           928              2  95.375128
# 2   19-03-2022              9          1135              5  99.213287
# 3   10-03-2022             40           956              0  95.983936
# 4   03-04-2022              5          1160             13  99.570815
# 5   15-02-2022              7           935              3  99.256900
# 6   13-02-2022              4           945              8  99.578504
# 7   11-02-2022              1           966              3  99.896587
# 8   01-04-2022              5          1120              8  99.555556
# 9   02-04-2022             32           958              2  96.767677
# 10  27-03-2022             30           933              2  96.884735
# 11  17-02-2022              7           922             10  99.246502
# 12  16-02-2022             29           831              1  96.627907
# 13  09-03-2022              8          1143              8  99.304952
# 14  13-03-2022              9          1152              8  99.224806
# 15  20-03-2022             46           946              2  95.362903
# 16  12-03-2022             28           934              2  97.089397
# 17  31-03-2022             35           928              4  96.365524
# 18  18-03-2022             36           929              3  96.269430
# 19  11-03-2022             11          1130              8  99.035933
# 20  12-02-2022             38           825              1  95.596756
# 21  04-03-2022             31           945              5  96.823770
# 22  01-03-2022              4          1129              7  99.646955
# 23  17-03-2022             10          1118              6  99.113475
# 24  30-03-2022              5          1127              9  99.558304
# 25  18-02-2022             28           825              2  96.717468
# 26  14-03-2022             36           937              1  96.300103
# 27  03-03-2022              5          1139              6  99.562937
# 28  05-04-2022              5          1144              8  99.564839
# 29  06-03-2022             36           949              1  96.345178
# 30  04-04-2022             31           908              2  96.698616
# 31  15-03-2022              7          1173             12  99.406780
# 32  16-03-2022             33           958              4  96.670030
# 33  26-03-2022              4          1151             11  99.653680
# 34  29-03-2022             40           931              6  95.880536
# 35  08-03-2022             31           930              3  96.774194
# 36  21-03-2022              3          1138              8  99.737073
# 37  28-03-2022              7          1122             10  99.379982
# 38  02-03-2022             27           981              4  97.321429
# 39  14-02-2022             34           813              4  95.985832
# 40  07-03-2022              6          1144              3  99.478261
# 41  23-03-2022             36           926              2  96.257796
# 42  05-03-2022              9          1136              9  99.213974
# 43  06-04-2022             37           921              3  96.137787

# %%
df_unique = []
for feature in df.columns:
    df_unique.append(df[feature].unique())
    print("Feature: " + feature + " : ")
    print("")
    print(df[feature].unique())
    print("-------------------------------------------------------------------------")
# Out:
# Feature: ID :
#
# ['0xb379' '0x5d6d' '0x7a6a' ... '0x4f8d' '0x5eee' '0x5fb2']
#  '15:50' '18:30' '18:15' '16:15' '11:15' '21:10' '22:30' '15:20' '18:40'
#  '23:20' '11:25' '13:55' '18:45' '22:05' '11:55' '18:55' '9:45' '17:15'
#  '12:05' '11:60' '19:35' '8:25' '11:05' '15:35' '12:40' '12:25' '8:20'
#  '23:25' '16:10' '8:15' '20:30' '12:60' '11:20' '8:50' '14:45' '17:45'
#  '9:60' '8:35' '12:10' '11:35' '14:30' '10:15' '17:05' '10:10' '9:35'
#  '11:30' '16:25' '9:15' '13:35' '15:55' '13:10' '13:05' '11:45' '16:20'
#  '16:30' '16:45' '9:20' '13:25' '14:15' '14:05' '16:35' '16:40' '13:30'
#  '14:40' '12:20' '13:50' '17:10' '15:25' '14:20' '12:35' '13:60' '14:10'
#  '14:55' '13:15' '14:50' '15:60']
# -------------------------------------------------------------------------
# Feature: Weather_conditions :
#
# ['Stormy' 'Sandstorms' 'Sunny' 'Cloudy' 'Fog' 'Windy' nan]
# -------------------------------------------------------------------------
# Feature: Road_traffic_density :
#
# ['Jam' 'Low' 'Medium' 'High' nan]
# -------------------------------------------------------------------------
# Feature: Vehicle_condition :
#
# [2 0 1 3]
# -------------------------------------------------------------------------
# Feature: Type_of_order :
#
# ['Snack' 'Drinks' 'Buffet' 'Meal']
# -------------------------------------------------------------------------
# Feature: Type_of_vehicle :
#
# ['scooter' 'motorcycle' 'electric_scooter' 'bicycle']
# -------------------------------------------------------------------------
# Feature: multiple_deliveries :
#
# [ 1.  3.  0. nan  2.]
# -------------------------------------------------------------------------
# Feature: Festival :
#
# ['No' 'Yes' nan]
# -------------------------------------------------------------------------
# Feature: City :
#
# ['Metropolitian' 'Urban' 'Semi-Urban' nan]
# -------------------------------------------------------------------------
# Feature: Time_taken_(min) :
#
# [33. 26. 21. 30. 40. 32. 34. 46. 23. 20. 41. 15. 36. 39. 18. 38. 47. 12.
#  22. 25. 35. 10. 19. 11. 28. 52. 16. 27. 49. 24. 17. 14. 37. 44. 42. 31.
#  13. 29. 50. 43. 48. 54. 53. 45. 51.]
# -------------------------------------------------------------------------

# %%
df['Restaurant_latitude'].unique()
# Out:
# array([ 12.913041,  12.914264,  11.003669,  12.972793,  17.431668,
#         23.369746,  12.352058,  17.433809,  30.327968,  10.003064,
#         18.56245 ,  30.899584,  26.463504,  19.176269,  12.311072,
#         18.592718,  17.426228,  22.552672,  18.563934,  23.357804,
#         12.986047,  19.221315,  13.005801,  26.849596,  21.160522,
#         12.934179,  18.51421 ,  11.022477,  21.160437,  15.51315 ,
#         15.561295,   0.      ,  18.55144 ,  18.593481,  21.173343,
#         17.451976,  12.972532,  13.064181,  19.121999,  21.149569,
#         19.091458,  22.539129,  12.970324,  21.175975,  11.003681,
#         10.96185 ,  27.165108,  26.88842 ,  26.913987,  12.3085  ,
#         21.183434,  19.254567,  25.449659,  30.372202,  21.157735,
#         21.186438,  12.935662,  17.431477,  12.933298,  22.311358,
#         12.934365,  13.086438,  26.913483,  17.411028,  18.516216,
#         15.5696  ,  19.876428,  12.939496,  23.374878, -27.163303,
#        -26.474133, -30.893384, -22.761226, -11.001852, -30.327968,
#        -22.745536, -17.455894, -26.481547, -22.32    , -23.371292,
#        -18.563934, -30.905562, -25.450377, -22.515082, -22.725748,
#        -23.351058, -26.473698, -23.333017, -30.873988,  -9.982834,
#        -22.514119, -21.170798, -12.979166, -19.065838, -19.876428,
#        -13.02978 , -12.310972, -22.307898, -21.170096, -21.186438,
#         -9.960846, -10.994136, -21.175104, -15.303897, -11.022477,
#        -26.846156, -25.457116, -26.905287, -21.149834, -30.328174,
#        -30.362686, -19.055831, -22.5491  , -26.471529, -12.934365,
#        -30.893244, -19.888716, -12.975377, -22.551084, -15.561295,
#        -22.695207, -26.956431,  -9.979186, -11.006686, -12.323225,
#        -13.026286, -25.454697, -23.357804, -19.880256, -13.081878,
#        -10.027014, -18.543626, -10.003064, -22.552996, -18.530963,
#        -19.866969, -22.75004 , -26.469003, -26.766536, -12.326356,
#        -22.577821, -22.569367, -23.232357, -13.091809, -12.933298,
#        -22.533662, -22.745049, -26.921411, -23.374878, -27.158822,
#        -12.906229, -13.044694, -13.045479, -12.98041 , -26.90294 ,
#        -23.369746, -19.875908, -26.479108, -30.892978, -23.232537,
#        -22.514585, -22.751234, -17.426228, -17.411028, -18.636215,
#        -15.56155 , -19.254567, -25.457687, -15.506205, -15.516833,
#        -11.02091 , -12.3085  , -26.47    , -19.003517, -30.890184,
#        -22.760072, -22.722634, -19.12663 , -22.753839, -21.173493,
#        -17.430448, -12.939496, -18.56245 , -22.308096, -23.264015,
#        -26.482581, -15.498603, -18.51421 , -12.975996, -19.874733,
#        -15.49395 , -12.978453])

# %%
len(df_unique[2])
# Out:
# 23

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.offline as py
import seaborn as sns

import matplotlib.ticker as mtick

# %%
a = np.array(df['Restaurant_latitude'])

# %%
for i in range(len(df.columns)):
    print(str(df.columns[i]) + " : " + str(len(df_unique[i])))
# Out:
# ID : 45592
# Delivery_person_ID : 1320
# Delivery_person_Age : 23
# Delivery_person_Ratings : 29
# Restaurant_latitude : 657
# Restaurant_longitude : 518
# Delivery_location_latitude : 4373
# Delivery_location_longitude : 4373
# Order_Date : 44
# Time_Orderd : 177
# Time_Order_picked : 193
# Weather_conditions : 7
# Road_traffic_density : 5
# Vehicle_condition : 4
# Type_of_order : 4
# Type_of_vehicle : 4
# multiple_deliveries : 5
# Festival : 3
# City : 4
# Time_taken_(min) : 45

# %%
# for feature in df.columns:
#         if feature in ('ID', 'Delivery_person_ID', 'Delivery_person_Age','Delivery_person_Ratings','Restaurant_latitude','Restaurant_longitude'
#     ,'Delivery_location_latitude','Delivery_location_longitude','Order_Date','Time_Orderd','Time_Order_picked','Time_taken_(min)'):
#             continue
#         x = df[feature].value_counts()

#         trace = go.Pie(labels = x.index, values = x, textinfo= 'value')

#         #layout = go.Layout(title = feature)

#         fig = go.Figure(data= [trace])
        
#         py.iplot(fig, image_width = 25, image_height = 25)

# %%
df['Time_taken_(min)']
# Out:
# 0        33.0
# 1        26.0
# 2        21.0
# 3        30.0
# 4        26.0
#          ...
# 45587    32.0
# 45588    36.0
# 45589    16.0
# 45590    26.0
# 45591    36.0
# Name: Time_taken_(min), Length: 45592, dtype: float64

# %%
sns.displot(df['Time_taken_(min)'], height= 3, aspect=2)
sns.displot(df['Delivery_person_Age'], height= 3, aspect=2)

# %%
slices = [((df['Delivery_person_Ratings'] >=1) & (df['Delivery_person_Ratings'] < 2)).sum(),
        ((df['Delivery_person_Ratings'] >=2) & (df['Delivery_person_Ratings'] < 3)).sum(),
        ((df['Delivery_person_Ratings'] >=3) & (df['Delivery_person_Ratings'] < 4)).sum(),
        ((df['Delivery_person_Ratings'] >=4) & (df['Delivery_person_Ratings'] < 5)).sum(),
        ((df['Delivery_person_Ratings'] >=5) & (df['Delivery_person_Ratings'] < 6)).sum()]

labels = ['1 <= Rating < 2','2 <= Rating < 3','3 <= Rating < 4','4 <= Rating < 5','5 <= Rating < 6']

# plt.pie(slices, labels= labels)
# fig = plt.gcf()

# fig.set_size_inches(4,4)

# plt.show()

x = df[feature].value_counts()

trace = go.Pie(labels = labels, values = slices, textinfo= 'value')

#layout = go.Layout(title = feature)

fig = go.Figure(data= [trace])

py.iplot(fig, image_width = 25, image_height = 25)

# %%
x = df_unique[18][:3]
y = np.array(df['City'].value_counts())
print(x)
print(y)
# Out:
# ['Metropolitian' 'Urban' 'Semi-Urban']
# [34093 10135   164]

# %%
df_unique
# Out:
# [array(['0xb379', '0x5d6d', '0x7a6a', ..., '0x4f8d', '0x5eee', '0x5fb2'],
#        dtype=object),
#  array(['BANGRES18DEL02', 'BANGRES19DEL01', 'COIMBRES13DEL02', ...,
#         'KOCRES04DEL01', 'BHPRES06DEL03', 'GOARES03DEL03'], dtype=object),
#  array([34., 23., 38., 32., 22., 33., 35., 36., 21., 24., 29., 25., 31.,
#         37., 27., 26., 20., nan, 28., 39., 30., 15., 50.]),
#  array([4.5, 4.4, 4.7, 4.6, 4.8, 4.2, 4.3, 4. , 4.9, 4.1, 5. , 3.5, nan,
#         3.8, 3.9, 3.7, 2.6, 2.5, 3.6, 3.1, 2.7, 1. , 3.2, 3.3, 6. , 3.4,
#         2.8, 2.9, 3. ]),
#  array([ 12.913041,  12.914264,  11.003669,  12.972793,  17.431668,
#          23.369746,  12.352058,  17.433809,  30.327968,  10.003064,
#          18.56245 ,  30.899584,  26.463504,  19.176269,  12.311072,
#          18.592718,  17.426228,  22.552672,  18.563934,  23.357804,
#          12.986047,  19.221315,  13.005801,  26.849596,  21.160522,
#          12.934179,  18.51421 ,  11.022477,  21.160437,  15.51315 ,
#          15.561295,   0.      ,  18.55144 ,  18.593481,  21.173343,
#          17.451976,  12.972532,  13.064181,  19.121999,  21.149569,
#          19.091458,  22.539129,  12.970324,  21.175975,  11.003681,
#          10.96185 ,  27.165108,  26.88842 ,  26.913987,  12.3085  ,
#          21.183434,  19.254567,  25.449659,  30.372202,  21.157735,
#          21.186438,  12.935662,  17.431477,  12.933298,  22.311358,
#          12.934365,  13.086438,  26.913483,  17.411028,  18.516216,
#          15.5696  ,  19.876428,  12.939496,  23.374878, -27.163303,
#          22.74806 ,  26.891191,  12.316967,  18.927584,  11.022298,
#         '10:25', '9:05', '16:50', '8:40', '23:40', '21:50', '19:55',
#         '14:60', '10:35', '9:25', '17:20', '17:25', '20:10', '23:60',
#         '17:35', '18:60', '19:05', '13:20', '17:50', '18:05', '19:20',
#         '10:05', '9:10', '21:55', '19:40', '9:50', '15:50', '18:30',
#         '18:15', '16:15', '11:15', '21:10', '22:30', '15:20', '18:40',
#         '23:20', '11:25', '13:55', '18:45', '22:05', '11:55', '18:55',
#         '9:45', '17:15', '12:05', '11:60', '19:35', '8:25', '11:05',
#         '15:35', '12:40', '12:25', '8:20', '23:25', '16:10', '8:15',
#         '20:30', '12:60', '11:20', '8:50', '14:45', '17:45', '9:60',
#         '8:35', '12:10', '11:35', '14:30', '10:15', '17:05', '10:10',
#         '9:35', '11:30', '16:25', '9:15', '13:35', '15:55', '13:10',
#         '13:05', '11:45', '16:20', '16:30', '16:45', '9:20', '13:25',
#         '14:15', '14:05', '16:35', '16:40', '13:30', '14:40', '12:20',
#         '13:50', '17:10', '15:25', '14:20', '12:35', '13:60', '14:10',
#         '14:55', '13:15', '14:50', '15:60'], dtype=object),
#  array(['Stormy', 'Sandstorms', 'Sunny', 'Cloudy', 'Fog', 'Windy', nan],
#        dtype=object),
#  array(['Jam', 'Low', 'Medium', 'High', nan], dtype=object),
#  array([2, 0, 1, 3], dtype=int64),
#  array(['Snack', 'Drinks', 'Buffet', 'Meal'], dtype=object),
#  array(['scooter', 'motorcycle', 'electric_scooter', 'bicycle'],
#        dtype=object),
#  array([ 1.,  3.,  0., nan,  2.]),
#  array(['No', 'Yes', nan], dtype=object),
#  array(['Metropolitian', 'Urban', 'Semi-Urban', nan], dtype=object),
#  array([33., 26., 21., 30., 40., 32., 34., 46., 23., 20., 41., 15., 36.,
#         39., 18., 38., 47., 12., 22., 25., 35., 10., 19., 11., 28., 52.,
#         16., 27., 49., 24., 17., 14., 37., 44., 42., 31., 13., 29., 50.,
#         43., 48., 54., 53., 45., 51.])]

# %%
# list_set_ID = set(df['ID'])
# list_set_Delivery_person_ID = set(df['Delivery_person_ID']) 
# list_set_Delivery_person_Age = set(df['Delivery_person_Age'])
# list_set_Delivery_person_Ratings = set(df['Delivery_person_Ratings'])
# list_set_Restaurant_latitude = set(df['Restaurant_latitude'])
# list_set_Restaurant_longitude = set(df['Restaurant_longitude']) 
# list_set_Delivery_location_latitude = set(df['Delivery_location_latitude'])
# list_set_Delivery_location_longitude = set(df['Delivery_location_longitude'])
# list_set_Order_Date = set(df['Order_Date']) 
# list_set_Time_Orderd = set(df['Time_Orderd'])
# list_set_Time_Order_picked = set(df['Time_Order_picked'])
# list_set_Weather_conditions = set(df['Weather_conditions']) 
# list_set_Road_traffic_density = set(df['Road_traffic_density'])
# list_set_Vehicle_condition = set(df['Vehicle_condition'])
# list_set_Type_of_order = set(df['Type_of_order'])
# list_set_Type_of_vehicle = set(df['Type_of_vehicle'])
# list_set_multiple_deliveries = set(df['multiple_deliveries']) 
# list_set_Festival = set(df['Festival'])
# list_set_City = set(df['City'])
# list_set_Time_taken = set(df['Time_taken_(min)'])
